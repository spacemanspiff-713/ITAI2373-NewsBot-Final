# %% [markdown]
# # NewsBot 2.0 — Multilingual demonstration
#
# This notebook imports reusable `src/` modules. Run it from the repository root after installing requirements.

# %%
import json
from src.multilingual import LanguageDetector, Translator
demo=json.load(open('data/demo/multilingual_demo.json')); [(x['id'],LanguageDetector().detect_language(x['text'])) for x in demo]
# Out:
# [('en_001',
#   {'language': 'en',
#    'language_name': 'English',
#    'confidence': 0.9999954730486496,
#    'is_supported': True,
#    'warning': None}),
#  ('es_001',
#   {'language': 'es',
#    'language_name': 'Spanish',
#    'confidence': 0.9999941005356101,
#    'is_supported': True,
#    'warning': None}),
#  ('fr_001',
#   {'language': 'fr',
#    'language_name': 'French',
#    'confidence': 0.9999959539819128,
#    'is_supported': True,
#    'warning': None}),
#  ('en_002',
#   {'language': 'en',
#    'language_name': 'English',
#    'confidence': 0.9999960035214895,
#    'is_supported': True,
#    'warning': None}),
#  ('es_002',
#   {'language': 'es',
#    'language_name': 'Spanish',
#    'confidence': 0.9999959734644626,
#    'is_supported': True,
#    'warning': None}),
#  ('fr_002',
#   {'language': 'fr',
#    'language_name': 'French',
#    'confidence': 0.9999982749155261,
#    'is_supported': True,
#    'warning': None})]

# %% [markdown]
# ## Limitations and ethics
# The corpus is historical and predominantly English. Model confidence is not truth; sentiment, NER, translation, and semantic similarity can be wrong. Internal corroboration is not fact-checking.
